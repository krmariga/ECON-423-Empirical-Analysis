# %%
import pandas as pd
import numpy as np
import mplfinance as mpf
from mplfinance.original_flavor import candlestick_ohlc
import matplotlib.dates as mpl_dates
import matplotlib.pyplot as plt
import statsmodels.api as sm
import yfinance
from statsmodels.tools.eval_measures import mse, rmse
from sklearn.metrics import mean_absolute_error
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [45,30]
plt.rc('font', size = 20)
import warnings
warnings.filterwarnings('ignore')

# %%
appl = pd.read_csv("/Users/kundaimariga/Downloads/AAPL.csv")

# %%
logappl = np.log(appl['Adj Close'])
logappl.diff()
rappl =100*(logappl.diff())
rappl = rappl.replace(np.nan, 0)

# %%
appl['return']= rappl

# %%
appl.set_index('Date')
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.562591
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.573935
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.469369
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.457407
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.500339
# ...                ...         ...         ...         ...         ...
# 2020-12-23  132.160004  132.429993  130.779999  130.960007  130.347565
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  131.352829
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  136.050766
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  134.239273
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  133.094650
#
#                Volume    return
# Date
# 2010-01-04  493729600  0.000000
# 2010-01-05  601904800  0.172709
# 2010-01-06  552160000 -1.603401
# 2010-01-07  477131200 -0.185073
# 2010-01-08  447610800  0.662649
# ...               ...       ...
# 2020-12-23   88223700 -0.700047
# 2020-12-24   54930100  0.768259
# 2020-12-28  124486200  3.514104
# 2020-12-29  121047300 -1.340427
# 2020-12-30   96452100 -0.856330
#
# [2768 rows x 7 columns]

# %%
appl = appl.astype({'Date': 'datetime64[ns]'})

# %% [markdown]
# # Check for autocorrlation and stationarity in adj close

# %%
plt.plot(appl['Adj Close'])

# %%
plot_acf(appl['Adj Close']);

# %%
#there is some serial correlation between returns.

# %%
from statsmodels.tsa.stattools import adfuller
dftest = adfuller(appl['Adj Close'], autolag = 'AIC')
print("1. ADF: ", dftest[0])
print("2. P-value: ", dftest[1])
print("3. Num of Lags: ", dftest[2])
print("4. Num of Observations used for ADF Regression and Critical Values Calculations: ", dftest[3])
print("5. Critical Values: ")
for key, val in dftest[4].items():
    print("\t", key, val)
# Out:
# 1. ADF:  3.5887938387619718
# 2. P-value:  1.0
# 3. Num of Lags:  28
# 4. Num of Observations used for ADF Regression and Critical Values Calculations:  2739
# 5. Critical Values:
# 	 1% -3.4327397185476918
# 	 5% -2.8625958054606793
# 	 10% -2.5673320392686283

# %%
#the data is non-stationary

# %%
#load tweet polarity data
appltweets = pd.read_csv("/Users/kundaimariga/Downloads/AAPL-5.csv")

# %%
appltweets
# Out:
#             date  ts_polarity  twitter_volume
# 0     2016-01-01     0.119693             417
# 1     2016-01-02     0.140774             495
# 2     2016-01-03     0.181132             518
# 3     2016-01-04     0.070389            1133
# 4     2016-01-05     0.133635            1430
# ...          ...          ...             ...
# 1336  2019-08-29     0.056460            1083
# 1337  2019-08-30     0.106096            1005
# 1338  2019-08-31     0.151625             224
# 1339  2019-09-01     0.059887             200
# 1340  2019-09-02     0.086850              74
#
# [1341 rows x 3 columns]

# %%
appltweets.shift(1)
appltweets = appltweets.replace(np.nan, 0)

# %%
appltweets
# Out:
#             date  ts_polarity  twitter_volume
# 0     2016-01-01     0.119693             417
# 1     2016-01-02     0.140774             495
# 2     2016-01-03     0.181132             518
# 3     2016-01-04     0.070389            1133
# 4     2016-01-05     0.133635            1430
# ...          ...          ...             ...
# 1336  2019-08-29     0.056460            1083
# 1337  2019-08-30     0.106096            1005
# 1338  2019-08-31     0.151625             224
# 1339  2019-09-01     0.059887             200
# 1340  2019-09-02     0.086850              74
#
# [1341 rows x 3 columns]

# %%
#need to rename data column so that I can merge it with the stock data
appltweets = appltweets.rename(columns={'date': 'Date'})

# %%
appltweets = appltweets.astype({'Date': 'datetime64[ns]'})

# %%
#merge tweet data
applfull = pd.merge(appl, appltweets, on = 'Date')
applfull = applfull.astype({'Date': 'datetime64[ns]'})
applnew = applfull.set_index('Date')
applnew
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2016-01-04  25.652500  26.342501  25.500000  26.337500  24.286833  270597600
# 2016-01-05  26.437500  26.462500  25.602501  25.677500  23.678219  223164000
# 2016-01-06  25.139999  25.592501  24.967501  25.174999  23.214844  273829600
# 2016-01-07  24.670000  25.032499  24.107500  24.112499  22.235069  324377600
# 2016-01-08  24.637501  24.777500  24.190001  24.240000  22.352642  283192000
# ...               ...        ...        ...        ...        ...        ...
# 2019-08-26  51.465000  51.797501  51.264999  51.622501  50.788677  104174400
# 2019-08-27  51.965000  52.137501  50.882500  51.040001  50.215584  103493200
# 2019-08-28  51.025002  51.430000  50.830002  51.382500  50.552551   63755200
# 2019-08-29  52.125000  52.330002  51.665001  52.252499  51.408504   83962000
# 2019-08-30  52.540001  52.612499  51.799999  52.185001  51.342091   84573600
#
#               return  ts_polarity  twitter_volume
# Date
# 2016-01-04  0.085482     0.070389            1133
# 2016-01-05 -2.537876     0.133635            1430
# 2016-01-06 -1.976369     0.072042            1949
# 2016-01-07 -4.312117     0.074369            2289
# 2016-01-08  0.527380     0.051595            2235
# ...              ...          ...             ...
# 2019-08-26  1.882097     0.072340             888
# 2019-08-27 -1.134802     0.117541             962
# 2019-08-28  0.668799     0.061477             895
# 2019-08-29  1.679020     0.056460            1083
# 2019-08-30 -0.129270     0.106096            1005
#
# [922 rows x 9 columns]

# %%
applnew.index
# Out:
# DatetimeIndex(['2016-01-04', '2016-01-05', '2016-01-06', '2016-01-07',
#                '2016-01-08', '2016-01-11', '2016-01-12', '2016-01-13',
#                '2016-01-14', '2016-01-15',
#                ...
#                '2019-08-19', '2019-08-20', '2019-08-21', '2019-08-22',
#                '2019-08-23', '2019-08-26', '2019-08-27', '2019-08-28',
#                '2019-08-29', '2019-08-30'],
#               dtype='datetime64[ns]', name='Date', length=922, freq=None)

# %%
#index the data by date
applnew['Date'] = pd.to_datetime(applnew.index)
applnew['Date'] = applnew['Date'].apply(mpl_dates.date2num)

applnew = applnew.loc[:,['Date', 'Adj Close','return','Volume', 'ts_polarity', 'twitter_volume']]
appl = applnew

# %%
appl = appl.replace(np.nan, 0)

# %%
appl
# Out:
#                Date  Adj Close    return     Volume  ts_polarity  \
# Date
# 2016-01-04  16804.0  24.286833  0.085482  270597600     0.070389
# 2016-01-05  16805.0  23.678219 -2.537876  223164000     0.133635
# 2016-01-06  16806.0  23.214844 -1.976369  273829600     0.072042
# 2016-01-07  16807.0  22.235069 -4.312117  324377600     0.074369
# 2016-01-08  16808.0  22.352642  0.527380  283192000     0.051595
# ...             ...        ...       ...        ...          ...
# 2019-08-26  18134.0  50.788677  1.882097  104174400     0.072340
# 2019-08-27  18135.0  50.215584 -1.134802  103493200     0.117541
# 2019-08-28  18136.0  50.552551  0.668799   63755200     0.061477
# 2019-08-29  18137.0  51.408504  1.679020   83962000     0.056460
# 2019-08-30  18138.0  51.342091 -0.129270   84573600     0.106096
#
#             twitter_volume
# Date
# 2016-01-04            1133
# 2016-01-05            1430
# 2016-01-06            1949
# 2016-01-07            2289
# 2016-01-08            2235
# ...                    ...
# 2019-08-26             888
# 2019-08-27             962
# 2019-08-28             895
# 2019-08-29            1083
# 2019-08-30            1005
#
# [922 rows x 6 columns]

# %%
plot_acf(appl['return'])

# %%
plt.plot(appl['return'])

# %% [markdown]
# # Check for ideal model

# %%
from pmdarima import auto_arima
import warnings
warnings.filterwarnings('ignore')

# %%
ideal_fit = auto_arima(appl['return'], trace=True, supress_warnings=True)
ideal_fit.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=3447.293, Time=0.94 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=3442.052, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=3443.913, Time=0.08 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=3443.904, Time=0.16 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=3442.548, Time=0.02 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=3443.550, Time=0.63 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 2.129 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  922
# Model:                        SARIMAX   Log Likelihood               -1719.026
# Date:                Thu, 09 Dec 2021   AIC                           3442.052
# Time:                        17:45:00   BIC                           3451.705
# Sample:                             0   HQIC                          3445.736
#                                 - 922
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0813      0.052      1.558      0.119      -0.021       0.184
# sigma2         2.4376      0.061     39.803      0.000       2.318       2.558
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.14   Jarque-Bera (JB):              1022.71
# Prob(Q):                              0.71   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.87   Skew:                            -0.45
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.08
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
#the model described above assumes that a model with just white noise is ideal. Looking at the plots for my data
#I dont believe this to be true due to the volatility shown

# %% [markdown]
# # MODEL 1 - ARIMAX model order (0,1,0)

# %%
print(appl.shape)
train = appl.iloc[:-30]
test = appl.iloc[-30:]
print(train.shape, test.shape)
# Out:
# (922, 6)
# (892, 6) (30, 6)

# %%
train.dtypes
# Out:
# Date              float64
# Adj Close         float64
# return            float64
# Volume              int64
# ts_polarity       float64
# twitter_volume      int64
# dtype: object

# %%
train
# Out:
#                Date  Adj Close    return     Volume  ts_polarity  \
# Date
# 2016-01-04  16804.0  24.286833  0.085482  270597600     0.070389
# 2016-01-05  16805.0  23.678219 -2.537876  223164000     0.133635
# 2016-01-06  16806.0  23.214844 -1.976369  273829600     0.072042
# 2016-01-07  16807.0  22.235069 -4.312117  324377600     0.074369
# 2016-01-08  16808.0  22.352642  0.527380  283192000     0.051595
# ...             ...        ...       ...        ...          ...
# 2019-07-15  18092.0  50.282806  0.935136   67789600     0.161794
# 2019-07-16  18093.0  50.108826 -0.346603   67467200     0.142708
# 2019-07-17  18094.0  49.827045 -0.563925   56430000     0.128261
# 2019-07-18  18095.0  50.393063  1.129562   74162400     0.132279
# 2019-07-19  18096.0  49.640816 -1.504013   83717200     0.081003
#
#             twitter_volume
# Date
# 2016-01-04            1133
# 2016-01-05            1430
# 2016-01-06            1949
# 2016-01-07            2289
# 2016-01-08            2235
# ...                    ...
# 2019-07-15             490
# 2019-07-16             676
# 2019-07-17             633
# 2019-07-18             775
# 2019-07-19             529
#
# [892 rows x 6 columns]

# %%
train['AdjClose'] = train['Adj Close']

# %%
test['AdjClose'] = test['Adj Close']

# %%
appl['AdjClose'] = appl['Adj Close']

# %%
dif=test['AdjClose'].diff()
dif = dif.replace(np.nan, 0)

# %%
import pyflux as pf
model = pf.ARIMAX(appl, formula='AdjClose~ts_polarity', ma=0, ar=0, integ=1,
              family=pf.Normal())
x = model.fit("MLE")
x.summary()
# Out:
# Normal ARIMAX(0,1,0)
# ======================================================= ==================================================
# Dependent Variable: Differenced AdjClose                Method: MLE
# Start Date: 2016-01-04 00:00:00                         Log Likelihood: -861.698
# End Date: 2019-08-30 00:00:00                           AIC: 1729.396
# Number of observations: 921                             BIC: 1743.8724
# ==========================================================================================================
# Latent Variable                          Estimate   Std Error  z        P>|z|    95% C.I.
# ======================================== ========== ========== ======== ======== =========================
# Beta 1                                   -0.0403    0.0472     -0.8547  0.3927   (-0.1327 | 0.0521)
# Beta ts_polarity                         0.7066     0.4315     1.6374   0.1015   (-0.1392 | 1.5524)
# Normal Scale                             0.6167
# ==========================================================================================================

# %%
model.plot_fit(figsize=(15,10))

# %%
model.plot_predict(h=7, oos_data=appl, figsize=(35,5))

# %%
model_est=model.predict(h=7, oos_data=appl,)
model_est
# Out:
#             Differenced AdjClose
# Date
# 2019-08-29              0.009429
# 2019-08-30              0.054118
# 2019-09-02              0.010597
# 2019-09-03              0.012241
# 2019-09-04             -0.003851
# 2019-09-05             -0.026570
# 2019-09-06              0.045448

# %%
model_est.values
# Out:
# array([[ 0.0094286 ],
#        [ 0.05411849],
#        [ 0.01059673],
#        [ 0.01224138],
#        [-0.00385132],
#        [-0.02656971],
#        [ 0.04544759]])

# %%
model_est = np.delete(model_est.values, [2])
model_est
# Out:
# array([ 0.0094286 ,  0.05411849,  0.01224138, -0.00385132, -0.02656971,
#         0.04544759])

# %%
futureobs = pd.read_csv("/Users/kundaimariga/Downloads/AAPL-13.csv")

# %%
futureobs = futureobs.set_index('Date')

# %%
futureobs['AdjClose'] = futureobs['Adj Close']
dif=futureobs['AdjClose'].diff()
dif = dif.replace(np.nan, 0)

# %%
dif = pd.DataFrame(dif)

# %%
dif
# Out:
#             AdjClose
# Date
# 2019-08-29  0.000000
# 2019-08-30 -0.066303
# 2019-09-03 -0.746639
# 2019-09-04  0.857155
# 2019-09-05  1.004524
# 2019-09-06 -0.004917

# %%
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import mse, rmse
from sklearn.metrics import r2_score
print('Mean Squared Error:', (mean_squared_error(dif, model_est)))
print('R-squared :', r2_score(dif, model_est))
# Out:
# Mean Squared Error: 0.3995853973664994
# R-squared : -0.12872987198588626

# %%
plt.plot(model_est, label = 'forecast')

# %%
plt.plot(dif, label='actual')

# %% [markdown]
# # MODEL 2 - ARIMAX model order (1,1,1)

# %%
model2 = pf.ARIMAX(appl, formula='AdjClose~ts_polarity', ma=1, ar=1, integ=1,
              family=pf.Normal())
x2 = model2.fit("MLE")
x2.summary()
# Out:
# Normal ARIMAX(1,1,1)
# ======================================================= ==================================================
# Dependent Variable: Differenced AdjClose                Method: MLE
# Start Date: 2016-01-05 00:00:00                         Log Likelihood: -860.6844
# End Date: 2019-08-30 00:00:00                           AIC: 1731.3687
# Number of observations: 920                             BIC: 1755.4906
# ==========================================================================================================
# Latent Variable                          Estimate   Std Error  z        P>|z|    95% C.I.
# ======================================== ========== ========== ======== ======== =========================
# AR(1)                                    0.0669     0.8993     0.0744   0.9407   (-1.6957 | 1.8295)
# MA(1)                                    -0.0731    0.9419     -0.0776  0.9382   (-1.9192 | 1.7731)
# Beta 1                                   -0.0384    0.0264     -1.4535  0.1461   (-0.0901 | 0.0134)
# Beta ts_polarity                         0.6748     0.4787     1.4098   0.1586   (-0.2634 | 1.613)
# Normal Scale                             0.6167
# ==========================================================================================================

# %%
model2.plot_fit(figsize=(15,10))

# %%
model2.plot_predict(h=7, oos_data=appl, figsize=(35,5))

# %%
model2_est=model2.predict(h=7, oos_data=appl,)
model2_est
# Out:
#             Differenced AdjClose
# Date
# 2019-08-29              0.011558
# 2019-08-30              0.052568
# 2019-09-02              0.013751
# 2019-09-03              0.012723
# 2019-09-04             -0.002714
# 2019-09-05             -0.025442
# 2019-09-06              0.041811

# %%
model2_est.values
# Out:
# array([[ 0.01155798],
#        [ 0.05256844],
#        [ 0.01375108],
#        [ 0.01272342],
#        [-0.00271358],
#        [-0.02544248],
#        [ 0.04181126]])

# %%
model2_est = np.delete(model2_est.values, [2])

# %%
model2_est
# Out:
# array([ 0.01155798,  0.05256844,  0.01272342, -0.00271358, -0.02544248,
#         0.04181126])

# %%
print('Mean Squared Error:', (mean_squared_error(dif, model2_est)))
print('R-squared :', r2_score(dif, model2_est))
# Out:
# Mean Squared Error: 0.398880624162487
# R-squared : -0.12673906207744912

# %%
plt.plot(model2_est, label = 'forecast')

# %%
plt.plot(dif, label='actual')

# %% [markdown]
# # MODEL 3 - ARIMAX model order (2,1,2)

# %%
model3 = pf.ARIMAX(appl, formula='AdjClose~ts_polarity', ma=2, ar=2, integ=1,
              family=pf.Normal())
x3 = model3.fit("MLE")
x3.summary()
# Out:
# Normal ARIMAX(2,1,2)
# ======================================================= ==================================================
# Dependent Variable: Differenced AdjClose                Method: MLE
# Start Date: 2016-01-06 00:00:00                         Log Likelihood: -859.0581
# End Date: 2019-08-30 00:00:00                           AIC: 1732.1163
# Number of observations: 919                             BIC: 1765.8793
# ==========================================================================================================
# Latent Variable                          Estimate   Std Error  z        P>|z|    95% C.I.
# ======================================== ========== ========== ======== ======== =========================
# AR(1)                                    0.1455     0.4428     0.3285   0.7425   (-0.7225 | 1.0135)
# AR(2)                                    -0.108     0.3524     -0.3065  0.7593   (-0.7988 | 0.5828)
# MA(1)                                    -0.1492    0.4414     -0.338   0.7353   (-1.0144 | 0.716)
# MA(2)                                    0.0633     0.3484     0.1817   0.8558   (-0.6196 | 0.7462)
# Beta 1                                   -0.0365    0.0464     -0.7871  0.4312   (-0.1273 | 0.0544)
# Beta ts_polarity                         0.6701     0.4649     1.4415   0.1494   (-0.241 | 1.5813)
# Normal Scale                             0.6162
# ==========================================================================================================

# %%
model3.plot_fit(figsize=(15,10))

# %%
model3.plot_predict(h=7, oos_data=test, figsize=(35,5))

# %%
model3_est=model3.predict(h=7, oos_data=appl,)
model3_est
# Out:
#             Differenced AdjClose
# Date
# 2019-08-29             -0.025315
# 2019-08-30              0.051128
# 2019-09-02              0.021967
# 2019-09-03              0.011028
# 2019-09-04             -0.002676
# 2019-09-05             -0.025033
# 2019-09-06              0.041494

# %%
model3_est.values
# Out:
# array([[-0.02531477],
#        [ 0.05112837],
#        [ 0.02196699],
#        [ 0.01102783],
#        [-0.00267566],
#        [-0.02503312],
#        [ 0.04149379]])

# %%
model3_est = np.delete(model3_est.values, [2])

# %%
model3_est
# Out:
# array([-0.02531477,  0.05112837,  0.01102783, -0.00267566, -0.02503312,
#         0.04149379])

# %%
print('Mean Squared Error:', (mean_squared_error(dif, model3_est)))
print('R-squared :', r2_score(dif, model3_est))
# Out:
# Mean Squared Error: 0.39832343017404387
# R-squared : -0.12516512693519477

# %%
plt.plot(model3_est, label = 'forecast')
